png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1120.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1121.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1122.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1123.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1124.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1125.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1126.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1127.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1128.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1129.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1130.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1131.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1132.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1133.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1134.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1135.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1136.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1137.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1138.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1139.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1140.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1141.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1142.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1143.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1144.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1145.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1146.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1147.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1148.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1149.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1150.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1151.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1152.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1153.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1154.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1155.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1156.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1157.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1158.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1159.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1160.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Non_Damage/Non_Damage_Wildlife_Forest/06_03_1161.png
# ...
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0831.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0832.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0833.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0834.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0835.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0836.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0837.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0838.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0839.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0840.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0841.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0842.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0843.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0844.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0845.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0846.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0847.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0848.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0849.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0850.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0851.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0852.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0853.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0854.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0855.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0856.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0857.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0858.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0859.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0860.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0861.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0862.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0863.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0864.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0865.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0866.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0867.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0868.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0869.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0870.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0871.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0872.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0873.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0874.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0875.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0876.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0877.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0878.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0879.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0880.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0881.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0882.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0883.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0884.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0885.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0886.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0887.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0888.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0889.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0890.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0891.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0892.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0893.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0894.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0895.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0896.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0897.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0898.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0899.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0900.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0901.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0902.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0903.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0904.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0905.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0906.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0907.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0908.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0909.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0910.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0911.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0912.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0913.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0914.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0915.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0916.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0917.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0918.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0919.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0920.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0921.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0922.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0923.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0924.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0925.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0926.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0927.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0928.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0929.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0930.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0931.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0932.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0933.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0934.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0935.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0936.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0937.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0938.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0939.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0940.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0941.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0942.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0943.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0944.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0945.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0946.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0947.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0948.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0949.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0950.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0951.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0952.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0953.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0954.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0955.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0956.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0957.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0958.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0959.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0960.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0961.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0962.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0963.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0964.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0965.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0966.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0967.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0968.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0969.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0970.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0971.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0972.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0973.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0974.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0975.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0976.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0977.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0978.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0979.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0980.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0981.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0982.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0983.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0984.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0985.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0986.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0987.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0988.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0989.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0990.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0991.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0992.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0993.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0994.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0995.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0996.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0997.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0998.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_0999.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1000.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1001.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1002.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1003.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1004.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1005.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1006.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1007.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1008.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1009.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1010.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1011.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1012.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1013.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1014.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1015.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1016.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1017.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1018.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1019.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1020.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1021.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1022.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1023.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1024.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1025.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1026.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1027.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1028.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1029.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1030.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1031.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1032.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1033.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1034.png
#   inflating: Comprehensive Disaster Dataset(CDD)/Water_Disaster/03_1035.png

# %%
import os
import shutil

base_dir='Comprehensive Disaster Dataset(CDD)'
output_dir='dataset'

category_map={
    "damaged":[
        'Damaged_Infrastructure/Earthquake',
    ],
    "fire":[
        "Fire_Disaster/Urban_Fire",
        "Fire_Disaster/Wild_Fire",
    ],
    "land":[
        "Land_Disaster/Land_Slide",
        "Land_Disaster/Drought",
    ],
    "water":[
        "Water_Disaster",
    ],
    "non_damage":[
        "Non_Damage/human",
        "Non_Damage/sea",
        "Non_Damage/Non_Damage_Buildings_Street",
        "Non_Damage/Non_Damage_Wildlife_Forest",
    ]
}
for category in category_map:
    os.makedirs(os.path.join(output_dir, category), exist_ok=True)

for category, folders in category_map.items():
    for folder in folders:
        folder_path = os.path.join(base_dir, folder)
        if os.path.exists(folder_path):
            for file_name in os.listdir(folder_path):
                src_file = os.path.join(folder_path, file_name)
                dst_file = os.path.join(output_dir, category, file_name)
                shutil.copy(src_file, dst_file)

# %%
import torch
# import torch.nn as nn
# import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, random_split
import os
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                            std=[0.229, 0.224, 0.225])
])

# %%
import numpy as np
from collections import Counter

# %%
dataset=datasets.ImageFolder("dataset", transform=transform)
class_names= dataset.classes
num_classes = len(class_names)

train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

train_labels=[ dataset.targets[i] for i in train_dataset.indices]
class_counts= Counter(train_labels)
total_samples = sum(class_counts.values())

class_weights=[total_samples / class_counts[label] for label in range(num_classes)]
class_weights = np.array(class_weights, dtype=np.float32)
class_weights= class_weights / class_weights.sum()
class_weights = torch.tensor(class_weights)


train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if(device.type == 'cuda'):
    print("Using GPU for training")
criterion = torch.nn.CrossEntropyLoss(weight=class_weights.to(device))
# Out:
# Using GPU for training

# %%
class SimpleCNN(torch.nn.Module):
    def __init__(self, num_classes):
        super(SimpleCNN, self).__init__()
        self.conv1 = torch.nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = torch.nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.fc1 = torch.nn.Linear(32 * 56 * 56, 128)
        self.fc2 = torch.nn.Linear(128, num_classes)
        self.relu = torch.nn.ReLU()
        self.dropout = torch.nn.Dropout(p=0.5)  # Dropout with a probability of 0.5
        self.pool = torch.nn.MaxPool2d(kernel_size=2, stride=2)

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = x.view(-1, 32 * 56 * 56)
        x = self.dropout(x)  # Apply dropout
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x


model = SimpleCNN(num_classes).to(device)

# %%
from tqdm.auto import tqdm

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
num_epochs = 3

history = {
    "train_loss": [],
    "val_loss": [],
    "val_accuracy": []
}

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct=0
    total=0

    loop= tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}", leave=False)
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        loop.set_description(f"Epoch {epoch+1}/{num_epochs} - Loss: {loss.item():.4f}, Accuracy: {100 * correct / total:.2f}%")
        loop.set_postfix(loss=loss.item())

    epoch_loss = running_loss / len(train_loader.dataset)
    history['train_loss'].append(epoch_loss)
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            val_loss += loss.item() * images.size(0)
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

        epoch_val_loss = val_loss / len(val_loader.dataset)
        epoch_val_accuracy = 100 * val_correct / val_total
        history['val_loss'].append(epoch_val_loss)
        history['val_accuracy'].append(epoch_val_accuracy)

        print(f"Validation Loss: {epoch_val_loss:.4f}, Validation Accuracy: {epoch_val_accuracy:.2f}%")


model_path = "simple_cnn.pth"
torch.save(model.state_dict(), model_path)
print(f"Model saved to {model_path}")
# Out:
# Epoch 1/3:   0%|          | 0/298 [00:00<?, ?it/s]
# Epoch [1/3], Loss: 1.4328
# Validation Loss: 1.1689, Validation Accuracy: 61.64%
# Epoch 2/3:   0%|          | 0/298 [00:00<?, ?it/s]
# Epoch [2/3], Loss: 0.9851
# Validation Loss: 1.0591, Validation Accuracy: 75.29%
# Epoch 3/3:   0%|          | 0/298 [00:00<?, ?it/s]
# Epoch [3/3], Loss: 0.7395
# Validation Loss: 1.0052, Validation Accuracy: 79.54%
# Model saved to simple_cnn.pth

# %%
history
# Out:
# {'train_loss': [1.509071688312371,
#   0.9740912678187122,
#   0.6826798423144667,
#   0.46450832742281034,
#   0.3108086426622804,
#   0.21593342739936058,
#   0.16843137769394498,
#   0.16482827267534192,
#   0.13694637277940286,
#   0.1553690024088175],
#  'val_loss': [1.1422405920108827,
#   1.0885479969136855,
#   0.9428384380180295,
#   1.076073118818908,
#   1.241291177773676,
#   1.3372311086213888,
#   1.813370633325657,
#   1.388096069337941,
#   1.7696018499987467,
#   1.9612700659687778],
#  'val_accuracy': [60.67226890756302,
#   79.91596638655462,
#   74.74789915966386,
#   76.00840336134453,
#   76.00840336134453,
#   83.82352941176471,
#   84.11764705882354,
#   83.36134453781513,
#   83.57142857142857,
#   85.0]}

# %%
#test the model
model.eval()
import torch
import torchvision.transforms as transforms
from torchvision import datasets

def predict_image(image_path, model, transform):
    image = datasets.folder.default_loader(image_path)
    image = transform(image).unsqueeze(0)
    image = image.to(device)

    with torch.no_grad():
        output = model(image)
        _, predicted = torch.max(output, 1)

    return class_names[predicted.item()]


image_path = "testphto.jpg"
predicted_class = predict_image(image_path, model, transform)
print(f"Predicted class: {predicted_class}")
# Out:
# Predicted class: fire

# %%
import matplotlib.pyplot as plt

plt.plot(history['train_loss'], label='Train Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
def plot_confustion_matrix(model,dataloader,class_names,title="Confusion Matrix"):

    y_true = []
    y_pred = []

    model.eval()
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())

    cm = confusion_matrix(y_true, y_pred, labels=range(len(class_names)))
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.tight_layout()
    plt.show()

# %%
plot_confustion_matrix(model, train_loader, class_names, title="Training Confusion Matrix")

# %%
plot_confustion_matrix(model, val_loader, class_names, title="Validation Confusion Matrix")
